# %% [markdown]
# # NOTEBOOK_NAME
#
# ---
#
# Description
#
# ---
#
# Goals:
# <br></br>
# - Goal_1
# - Goal_2
# - Goal_3
# <br></br>
# ---
#
# Requirements:
# <br></br>
# - Req_1
# - Req_2
# - Req_3
# <br></br>
# ---
#
# Additional Notes:
# <br></br>
# - Note_1
# - Note_2
# - Note_3

# %% [markdown]
# ## MAIN

# %% [markdown]
# ### Views

# %% [markdown]
# #### View_1

# %% [markdown]
# #### View_2

# %% [markdown]
# #### View_3

# %% [markdown]
# ### Table Build

# %% [markdown]
# ### Notebook Exit

# %%
# Make sure to add:
# %python
# if converting to a SQL notebook.
dbutils.notebook.exit("Table Build Complete - Exit Notebook")

# %% [markdown]
# ## TESTS

# %% [markdown]
# ### Initial Tests

# %% [markdown]
# #### Test_Subsection_1

# %% [markdown]
# ##### Test_1

# %% [markdown]
# ##### Test_2

# %% [markdown]
# ##### Test_3

# %% [markdown]
# #### Test_Subsection_2

# %% [markdown]
# ##### Test_1

# %% [markdown]
# ##### Test_2

# %% [markdown]
# ##### Test_3

# %% [markdown]
# ### Build Tests

# %% [markdown]
# #### Test_Subsection_1

# %% [markdown]
# ##### Test_1

# %% [markdown]
# ##### Test_2

# %% [markdown]
# ##### Test_3

# %% [markdown]
# #### Test_Subsection_2

# %% [markdown]
# ##### Test_1

# %% [markdown]
# ##### Test_2

# %% [markdown]
# ##### Test_3

# %% [markdown]
# ### Final Tests

# %% [markdown]
# #### Test_Subsection_1

# %% [markdown]
# ##### Test_1

# %% [markdown]
# ##### Test_2

# %% [markdown]
# ##### Test_3

# %% [markdown]
# #### Test_Subsection_2

# %% [markdown]
# ##### Test_1

# %% [markdown]
# ##### Test_2

# %% [markdown]
# ##### Test_3

# %% [markdown]
# ## END
